# %%
using MimiCIAM
using Mimi

# %%
m = MimiCIAM.get_model()
run(m)

# %%
m[:slrcost, :NoAdaptCost][:,1]
# Out:
# 20-element Vector{Union{Missing, Float64}}:
#  0.0006665021679208962
#  0.001685252607895144
#  0.0066365250004638094
#  0.03152990011066583
#  0.04820290338429678
#  0.055376926044734286
#  0.0608845042740465
#  0.06271985386656528
#  0.06273364632202484
#  0.05962544353200111
#  0.06269404109612917
#  0.06498804269587775
#  0.0687781324182431
#  0.07231560704855108
#  0.07523991975094899
#  0.0789508106581279
#  0.08250375735492096
#  0.08240755470176922
#  0.0851518351752692
#  0.08554850554222129

# %% [markdown]
# Unit test:  the first segment shoudl give this as the NoAdaptCost:
# ```
# 0-element Vector{Union{Missing, Float64}}:
#  0.0006665021679208962
#  0.001685252607895144
#  0.0066365250004638094
#  0.03152990011066583
#  0.04820290338429678
#  0.055376926044734286
#  0.0608845042740465
#  0.06271985386656528
#  0.06273364632202484
#  0.05962544353200111
#  0.06269404109612917
#  0.06498804269587775
#  0.0687781324182431
#  0.07231560704855108
#  0.07523991975094899
#  0.0789508106581279
#  0.08250375735492096
#  0.08240755470176922
#  0.0851518351752692
#  0.08554850554222129
# ```

# %%
using Plots

# %%
plot(m[:slrcost,:NoAdaptCost][:,1])

# %% [markdown]
# ![alt-text](figs/GMSL_2100_ssp-rcp.png)

# %%
my_subset_file = "/Users/aewsma/Downloads/segments_usa.csv"
# Out:
# "/Users/aewsma/Downloads/segments_usa.csv"

# %%
run_name = "my_subset_run"

init_settings = Dict(
        :init_filename   => string("$run_name", "_init.csv"),
        :lslrfile        => "lsl_rcp85_p50.csv",
        :subset          => my_subset_file,
        :ssp             => "IIASAGDP_SSP5_v9_130219",
        :ssp_simplified  => 5
    )

MimiCIAM.write_init_file(run_name, "..", init_settings)
# Out:
# 98

# %%
m_usa = MimiCIAM.get_model(initfile="../my_subset_run_init.csv")
# Out:
# Mimi.Model
#   Module: Mimi
#   Components:
#     ComponentId(MimiCIAM.slrcost)
#   Built: false

# %%
run(m_usa)

# %%
m_usa[:slrcost, :NoAdaptCost]
# Out:
# 20×1077 Matrix{Union{Missing, Float64}}:
#  0.0346601  0.00524383  0.00448586  …  0.00291525  0.00514672  0.00660525
#  0.0597209  0.0113183   0.00920726     0.00406398  0.00827324  0.0106829
#  0.118471   0.0588036   0.0490733      0.00579766  0.0126749   0.0164186
#  0.238768   0.242482    0.304296       0.00920497  0.0231145   0.0300781
#  0.324924   0.293247    0.387907       0.0129333   0.0358226   0.0466995
#  0.415451   0.350144    0.460095    …  0.0123417   0.0475967   0.0614994
#  0.401058   0.389165    0.519014       0.0167124   0.0614235   0.0783192
#  0.497484   0.446366    0.593097       0.0216128   0.0793264   0.0978889
#  0.53599    0.492897    0.655721       0.0216539   0.066889    0.0791765
#  0.624448   0.541141    0.717649       0.0260571   0.080165    0.0925851
#  0.717917   0.555364    0.730971    …  0.0318871   0.122227    0.133709
#  0.74796    0.558039    0.733422       0.034807    0.134916    0.142465
# ...
